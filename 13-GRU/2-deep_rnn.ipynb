# %% [markdown]
# ## Deep RNN
# - Deep RNN is adding more Neural Network Layer for optimizing the the model prediction.
#
# ![image-2.png](attachment:image-2.png)
#
#
# ## Playground
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Why and When to use ?
# ![image.png](attachment:image.png)

# %% [markdown]
# ## When to use Deep RNN?
# - Complex task
#   - Speech Recognition
#   - Machine transalation
# - Large dataset
# - If you have Computation Resources.
# - When not satisfield with Simple RNN.

# %% [markdown]
# ## Disadvantages
# - Overfitting
# - Training time
