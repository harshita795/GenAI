# %% [markdown]
# # NLP in ML
#
# ML
# - Supervised
#    - Classification
#    - Regression
# - Unsupervised

# %%
# f1, f2, f3, f4 # Independent feature
# o/p # output/dependent feature

# spam classification -> Email -> spam or not spam

# Email Subject -> text
# Email Body -> text

# Model is not directly able to understand natural language, so we convert them into meaningful vector.

# %% [markdown]
# Example of NLP
# - Alexa
# - Google Home

# %% [markdown]
# ![image.png](attachment:image.png)
