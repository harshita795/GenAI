# %% [markdown]
# ### NLP in deep Learning
# - ANN (Artificial neural network)
#   - Classification
#   - Regression
#
# eg-  House Price Prediction
#  (sequence of data not matter)
#
# - CNN (Convolutional neural network)
# Data in the form of images
#   - Image classification
#   - Object Objection
#
# - Data od Sequencial type (Sequencial data) Sequential data is data where the order of elements matters.
#   - Text Generation
#   - Chatbot
#   - Language Translation
#   - Auto Suggestion
#   - Sales Data (based on datetime)
#
# Can we use ANN to solve this problem ?
# No Because we loose sequence of words here. so context loss. We will use RNN.
#
#
# ### Topis to learn next
# - ANN vs RNN
# - Simple RNN
# - LSTM/GRU RNN
# - Bidirectional RNN
# - Encoder Decoder
# - Self Attention
# - Transformers
