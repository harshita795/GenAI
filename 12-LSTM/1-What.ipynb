# %% [markdown]
# ## LSTM
# - LSTM have both long term memory and short term memory.
# - Complex Architecture for communication between short term and long term memory.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# - Forget gate remove the input
# - Input gate add the input
# - Output gate provide output example yes or no for text classification.
# - Output gate also provide short term memory.
#
# ![image-3.png](attachment:image-3.png)
