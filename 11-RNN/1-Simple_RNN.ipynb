# %% [markdown]
# - RNN is the type of sequential model to work on sequential data.
# - eg - text data, here sequence matter
#
# ## why RNN not ANN?
# - text input -> varying size.
# - zero padding if applied -> unnecessary computation cost -> problem in prdiction.
# - Totaly disregarding the sequence information.
#
# ## RNN Applications
# - Sentiment Analysis
# - Sentence Completion
# - Image Caption Generator
# - Google translation
# - Question Answering system
# - Speech Recognition

# %% [markdown]
# # Simple RNN
# ![image.png](attachment:image.png)
# - We input data in RNN in the form timesteps, input-features.
# - We create vocabulary of unique words.
# - We will do One Hot Encoding.
# - When we put first word in RNN, then first word called t=1 (t is time), second word at t=2.
# - So if a Review has three words, and 5 unique words in vocabulary, so we represent them as (3,5) -> (timesteps, input-features).
# - When we use keras -> In simple RNN -> we send data like this ->
# batchsize, timesteps, input-features
# (3,4,5)
#
# ## How RNN works?
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## RNN forword propagation
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# - The forward propagation of a Recurrent Neural Network (RNN) computes the sequence of hidden states and outputs step-by-step through time. At each time step t, the network processes the current input \(x_{t}\) alongside the hidden state from the previous step \(h_{t-1}\) to update its memory and make a prediction.

# %% [markdown]
# ## Types of RNN
# - Many to One
#   - Sentiment analysis
#   - Rating Prediction
# - One to Many
#   - Image Captioning
# - Many to Many (seq2seq model)[2 types ->  same length and variable length]
#   - Google Translation
# - One to One (not RNN) -> No sequence
#   - Image classification

# %% [markdown]
# ## Back Propagation
# - In RNN its called BPTT (Back Propagation Through Time)
# - We take an example of Many to One RNN -> Sentiment Analysis (text -> 1/0)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# - It unfolded 3 times, because we have three words in first review.
# - If there were 10 words it will be 10 terms.
# - And its not feaseable.
# - So we will do this.
# ![image-6.png](attachment:image-6.png)
# ![image-5.png](attachment:image-5.png)
# - Now last.
# ![image-7.png](attachment:image-7.png)
# - Now we can apply gradient descent.
# ![image-8.png](attachment:image-8.png)
